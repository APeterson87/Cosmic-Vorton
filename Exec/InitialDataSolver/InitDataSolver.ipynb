# %%
import yt
import numpy as np

# %%
plot_num = 2
diag_num = 2
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2023-01-26 22:03:39,957 Parameters: current_time              = 0.064
# yt : [INFO     ] 2023-01-26 22:03:39,958 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-01-26 22:03:39,958 Parameters: domain_left_edge          = [-1024. -1024. -1024.]
# yt : [INFO     ] 2023-01-26 22:03:39,959 Parameters: domain_right_edge         = [1024. 1024. 1024.]
# yt : [INFO     ] 2023-01-26 22:03:40,018 Parameters: current_time              = 0.064
# yt : [INFO     ] 2023-01-26 22:03:40,019 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-01-26 22:03:40,020 Parameters: domain_left_edge          = [-1024. -1024. -1024.]
# yt : [INFO     ] 2023-01-26 22:03:40,021 Parameters: domain_right_edge         = [1024. 1024. 1024.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'A'), ('boxlib', 'B'), ('boxlib', 'V'), ('boxlib', 'chi'), ('boxlib', 'u')]
# []

# %%
var = 'chi'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'u'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'V'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2023-01-26 22:03:41,296 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:41,297 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:41,297 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:41,298 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:41,299 Making a fixed resolution buffer of (('boxlib', 'chi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-26 22:03:42,199 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:42,200 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:42,201 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:42,203 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:42,204 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [WARNING  ] 2023-01-26 22:03:42,275 Plotting ('boxlib', 'u'): Both positive and negative values. Min = -1.538151174403988e-21 dimensionless, Max = 6.134146289541962e-06 dimensionless.
# yt : [WARNING  ] 2023-01-26 22:03:42,276 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-26 22:03:45,287 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-26 22:03:45,931 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:45,933 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:45,934 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:45,935 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-26 22:03:45,937 Making a fixed resolution buffer of (('boxlib', 'V')) 800 by 800
# yt : [WARNING  ] 2023-01-26 22:03:46,019 Plotting ('boxlib', 'V'): Wide range and zeros.
# yt : [WARNING  ] 2023-01-26 22:03:46,020 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-26 22:03:46,843 Making a fixed resolution buffer of (('boxlib', 'V')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
