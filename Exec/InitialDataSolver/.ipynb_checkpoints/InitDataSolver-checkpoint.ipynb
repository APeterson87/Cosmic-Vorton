# %%
import yt
import numpy as np
# Out:
# /home/ThirdEye87/.local/lib/python3.8/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /home/ThirdEye87/.config/yt/ytrc is deprecated in favor of /home/ThirdEye87/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
plot_num = 50000
diag_num = 0
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
# Out:
# yt : [INFO     ] 2022-12-20 19:19:42,328 Parameters: current_time              = 160000.00000002107
# yt : [INFO     ] 2022-12-20 19:19:42,329 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-12-20 19:19:42,329 Parameters: domain_left_edge          = [-1024. -1024. -1024.]
# yt : [INFO     ] 2022-12-20 19:19:42,330 Parameters: domain_right_edge         = [1024. 1024. 1024.]

# %%
print(dplot.field_list)
# Out:
# [('boxlib', 'A'), ('boxlib', 'B'), ('boxlib', 'V'), ('boxlib', 'u')]

# %%
var = 'u'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2022-12-20 19:19:43,582 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2022-12-20 19:19:43,582 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2022-12-20 19:19:43,583 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2022-12-20 19:19:43,583 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2022-12-20 19:19:43,584 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
