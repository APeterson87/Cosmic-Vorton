# %%
import yt
import numpy as np
# Out:
# /home/ThirdEye87/.local/lib/python3.8/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /home/ThirdEye87/.config/yt/ytrc is deprecated in favor of /home/ThirdEye87/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
plot_num = 10
diag_num = 10
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2023-01-25 19:49:11,339 Parameters: current_time              = 15.999999999999998
# yt : [INFO     ] 2023-01-25 19:49:11,340 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-01-25 19:49:11,341 Parameters: domain_left_edge          = [-1024. -1024. -1024.]
# yt : [INFO     ] 2023-01-25 19:49:11,343 Parameters: domain_right_edge         = [1024. 1024. 1024.]
# yt : [INFO     ] 2023-01-25 19:49:11,403 Parameters: current_time              = 15.999999999999998
# yt : [INFO     ] 2023-01-25 19:49:11,404 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-01-25 19:49:11,405 Parameters: domain_left_edge          = [-1024. -1024. -1024.]
# yt : [INFO     ] 2023-01-25 19:49:11,406 Parameters: domain_right_edge         = [1024. 1024. 1024.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'A'), ('boxlib', 'A_L_0'), ('boxlib', 'A_L_1'), ('boxlib', 'A_L_2'), ('boxlib', 'B'), ('boxlib', 'C'), ('boxlib', 'S_U_phi'), ('boxlib', 'V'), ('boxlib', 'chi'), ('boxlib', 'delta1'), ('boxlib', 'delta2'), ('boxlib', 'phi1'), ('boxlib', 'phi2'), ('boxlib', 'sigma1'), ('boxlib', 'sigma2'), ('boxlib', 'u'), ('boxlib', 'w_U_0'), ('boxlib', 'w_U_1'), ('boxlib', 'w_U_2')]
# [('boxlib', 'w_U_phi')]

# %%
var = 'w_U_phi'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'chi'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'u'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'w_U_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'w_U_1'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'S_U_phi'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'A'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'B'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,10])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0, 10**(-5))
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'C'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'V'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2023-01-25 19:49:13,200 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:13,201 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:13,203 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:13,204 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:13,205 Making a fixed resolution buffer of (('boxlib', 'w_U_phi')) 800 by 800
# yt : [WARNING  ] 2023-01-25 19:49:13,258 Plotting ('boxlib', 'w_U_phi'): Both positive and negative values. Min = -1.2180913611817005e-05 dimensionless, Max = 6.238597133868686e-10 dimensionless.
# yt : [WARNING  ] 2023-01-25 19:49:13,258 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-25 19:49:16,148 Making a fixed resolution buffer of (('boxlib', 'w_U_phi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:16,917 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:16,917 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:16,918 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:16,919 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:16,920 Making a fixed resolution buffer of (('boxlib', 'chi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:17,816 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:17,816 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:17,818 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:17,819 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:17,821 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [WARNING  ] 2023-01-25 19:49:17,889 Plotting ('boxlib', 'u'): Both positive and negative values. Min = -1.4970185472830238e-06 dimensionless, Max = 0.03316469071405425 dimensionless.
# yt : [WARNING  ] 2023-01-25 19:49:17,890 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-25 19:49:20,867 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:21,624 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:21,625 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:21,626 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:21,626 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:21,627 Making a fixed resolution buffer of (('boxlib', 'w_U_0')) 800 by 800
# yt : [WARNING  ] 2023-01-25 19:49:21,678 Plotting ('boxlib', 'w_U_0'): Both positive and negative values. Min = -0.0023872737821887344 dimensionless, Max = 0.0023872737821888407 dimensionless.
# yt : [WARNING  ] 2023-01-25 19:49:21,679 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-25 19:49:24,767 Making a fixed resolution buffer of (('boxlib', 'w_U_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:25,365 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:25,365 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:25,366 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:25,367 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:25,368 Making a fixed resolution buffer of (('boxlib', 'w_U_1')) 800 by 800
# yt : [WARNING  ] 2023-01-25 19:49:25,445 Plotting ('boxlib', 'w_U_1'): Both positive and negative values. Min = -0.0023872737821888407 dimensionless, Max = 0.0023872737821887344 dimensionless.
# yt : [WARNING  ] 2023-01-25 19:49:25,446 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-25 19:49:28,428 Making a fixed resolution buffer of (('boxlib', 'w_U_1')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:29,051 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:29,052 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:29,053 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:29,054 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:29,055 Making a fixed resolution buffer of (('boxlib', 'S_U_phi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:30,171 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:30,171 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:30,172 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:30,173 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:30,174 Making a fixed resolution buffer of (('boxlib', 'A')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:31,131 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:31,131 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:31,132 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:31,133 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:31,133 Making a fixed resolution buffer of (('boxlib', 'B')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:32,187 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:32,188 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:32,189 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:32,189 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:32,190 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-25 19:49:33,098 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:33,099 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:33,100 xlim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:33,100 ylim = -1024.000000 1024.000000
# yt : [INFO     ] 2023-01-25 19:49:33,101 Making a fixed resolution buffer of (('boxlib', 'V')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
