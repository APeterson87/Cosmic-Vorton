# %%
import yt
import numpy as np

# %%
plot_num = 30
diag_num = 30
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

# %%
dplot = yt.load(plotname)
ddiag = yt.load(diagname)
# Out:
# yt : [INFO     ] 2023-01-27 14:00:56,377 Parameters: current_time              = 192.00000000000009
# yt : [INFO     ] 2023-01-27 14:00:56,378 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-01-27 14:00:56,379 Parameters: domain_left_edge          = [-2048. -2048. -2048.]
# yt : [INFO     ] 2023-01-27 14:00:56,379 Parameters: domain_right_edge         = [2048. 2048. 2048.]
# yt : [INFO     ] 2023-01-27 14:00:56,445 Parameters: current_time              = 192.00000000000009
# yt : [INFO     ] 2023-01-27 14:00:56,445 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2023-01-27 14:00:56,446 Parameters: domain_left_edge          = [-2048. -2048. -2048.]
# yt : [INFO     ] 2023-01-27 14:00:56,447 Parameters: domain_right_edge         = [2048. 2048. 2048.]

# %%
print(dplot.field_list)
print(ddiag.field_list)
# Out:
# [('boxlib', 'A'), ('boxlib', 'A_L_0'), ('boxlib', 'A_L_1'), ('boxlib', 'A_L_2'), ('boxlib', 'B'), ('boxlib', 'C'), ('boxlib', 'S_U_phi'), ('boxlib', 'V'), ('boxlib', 'chi'), ('boxlib', 'delta1'), ('boxlib', 'delta2'), ('boxlib', 'phi1'), ('boxlib', 'phi2'), ('boxlib', 'sigma1'), ('boxlib', 'sigma2'), ('boxlib', 'u'), ('boxlib', 'w_U_0'), ('boxlib', 'w_U_1'), ('boxlib', 'w_U_2')]
# [('boxlib', 'w_U_phi')]

# %%
var = 'w_U_phi'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,10.0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'u'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,10.0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
#s.annotate_grids()
s.zoom(1)
s.show()

var = 'chi'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'V'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()


var = 'w_U_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'w_U_1'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'S_U_phi'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'A'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'B'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,10])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0, 10**(-5))
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'C'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()

var = 'V'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native')
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.hide_colorbar()
#s.annotate_cell_edges()
s.annotate_grids()
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2023-01-27 14:00:57,576 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:57,577 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:57,579 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:57,579 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:57,581 Making a fixed resolution buffer of (('boxlib', 'w_U_phi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:00:58,560 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:58,560 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:58,562 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:58,562 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:00:58,563 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# yt : [WARNING  ] 2023-01-27 14:00:58,643 Plotting ('boxlib', 'u'): Both positive and negative values. Min = -1.4871508728305344e-07 dimensionless, Max = 0.025966664615817592 dimensionless.
# yt : [WARNING  ] 2023-01-27 14:00:58,644 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-27 14:01:00,074 Making a fixed resolution buffer of (('boxlib', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:00,795 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:00,795 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:00,796 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:00,797 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:00,798 Making a fixed resolution buffer of (('boxlib', 'chi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:01,697 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:01,698 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:01,699 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:01,699 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:01,700 Making a fixed resolution buffer of (('boxlib', 'V')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:02,726 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:02,726 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:02,728 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:02,728 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:02,730 Making a fixed resolution buffer of (('boxlib', 'w_U_0')) 800 by 800
# yt : [WARNING  ] 2023-01-27 14:01:02,806 Plotting ('boxlib', 'w_U_0'): Both positive and negative values. Min = -0.0022795625006734464 dimensionless, Max = 0.0022795625079969507 dimensionless.
# yt : [WARNING  ] 2023-01-27 14:01:02,806 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-27 14:01:04,292 Making a fixed resolution buffer of (('boxlib', 'w_U_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:04,943 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:04,944 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:04,945 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:04,945 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:04,947 Making a fixed resolution buffer of (('boxlib', 'w_U_1')) 800 by 800
# yt : [WARNING  ] 2023-01-27 14:01:05,035 Plotting ('boxlib', 'w_U_1'): Both positive and negative values. Min = -0.002279562581255099 dimensionless, Max = 0.0022795625812551843 dimensionless.
# yt : [WARNING  ] 2023-01-27 14:01:05,036 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-27 14:01:06,504 Making a fixed resolution buffer of (('boxlib', 'w_U_1')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:07,281 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:07,282 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:07,284 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:07,285 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:07,286 Making a fixed resolution buffer of (('boxlib', 'S_U_phi')) 800 by 800
# yt : [WARNING  ] 2023-01-27 14:01:07,379 Plotting ('boxlib', 'S_U_phi'): Wide range and zeros.
# yt : [WARNING  ] 2023-01-27 14:01:07,380 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-27 14:01:08,054 Making a fixed resolution buffer of (('boxlib', 'S_U_phi')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:08,707 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:08,708 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:08,710 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:08,711 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:08,713 Making a fixed resolution buffer of (('boxlib', 'A')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:09,866 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:09,867 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:09,868 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:09,868 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:09,869 Making a fixed resolution buffer of (('boxlib', 'B')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:10,876 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:10,876 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:10,878 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:10,878 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:10,879 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# yt : [WARNING  ] 2023-01-27 14:01:10,961 Plotting ('boxlib', 'C'): Wide range and zeros.
# yt : [WARNING  ] 2023-01-27 14:01:10,962 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2023-01-27 14:01:11,859 Making a fixed resolution buffer of (('boxlib', 'C')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2023-01-27 14:01:12,496 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:12,497 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:12,499 xlim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:12,500 ylim = -2048.000000 2048.000000
# yt : [INFO     ] 2023-01-27 14:01:12,501 Making a fixed resolution buffer of (('boxlib', 'V')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg["u"][:,:,:].d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-fcb35a426990> in <module>
# ----> 1 cg = ds.covering_grid(left_edge=ds.domain_left_edge, dims=ds.domain_dimensions, level=0)
#       2 coords = cg.fcoords
#       3
#       4 xs = coords[:,0]
#       5 ys = coords[:,1]
#
# NameError: name 'ds' is not defined

# %%
H[64, 64, 64]
# Out:
# 0.0081254919985896176

# %%
H[64, 64, 64]
# Out:
# 1.2775443176769271e-10

# %%
H[0, 0, 0]
# Out:
# 0.0010225271343679068
